# %% [markdown]
# ## Welcome to the Second Lab - Week 1, Day 3
#
# Today we will work with lots of models! This is a way to get comfortable with APIs.

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Important point - please read</h2>
#             <span style="color:#ff7800;">The way I collaborate with you may be different to other courses you've taken. I prefer not to type code while you watch. Rather, I execute Jupyter Labs, like this, and give you an intuition for what's going on. My suggestion is that you carefully execute this yourself, <b>after</b> watching the lecture. Add print statements to understand what's going on, and then come up with your own variations.<br/><br/>If you have time, I'd love it if you submit a PR for changes in the community_contributions folder - instructions in the resources. Also, if you have a Github account, use this to showcase your variations. Not only is this essential practice, but it demonstrates your skills to others, including perhaps future clients or employers...
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# Start with imports - ask ChatGPT to explain any package that you don't know

import os
import json
from dotenv import load_dotenv
from openai import OpenAI
from anthropic import Anthropic
from IPython.display import Markdown, display

# %%
# Always remember to do this!
load_dotenv(override=True)
# Out:
# True

# %%
# Print the key prefixes to help with any debugging

openai_api_key = os.getenv('OPENAI_API_KEY')
anthropic_api_key = os.getenv('ANTHROPIC_API_KEY')
google_api_key = os.getenv('GOOGLE_API_KEY')
deepseek_api_key = os.getenv('DEEPSEEK_API_KEY')
groq_api_key = os.getenv('GROQ_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set")
    
if anthropic_api_key:
    print(f"Anthropic API Key exists and begins {anthropic_api_key[:7]}")
else:
    print("Anthropic API Key not set (and this is optional)")

if google_api_key:
    print(f"Google API Key exists and begins {google_api_key[:2]}")
else:
    print("Google API Key not set (and this is optional)")

if deepseek_api_key:
    print(f"DeepSeek API Key exists and begins {deepseek_api_key[:3]}")
else:
    print("DeepSeek API Key not set (and this is optional)")

if groq_api_key:
    print(f"Groq API Key exists and begins {groq_api_key[:4]}")
else:
    print("Groq API Key not set (and this is optional)")
# Out:
# OpenAI API Key not set
# Anthropic API Key not set (and this is optional)
# Google API Key exists and begins AI
# DeepSeek API Key not set (and this is optional)
# Groq API Key not set (and this is optional)

# %%
request = "Please come up with a challenging, nuanced question that I can ask a number of LLMs to evaluate their intelligence. "
request += "Answer only with the question, no explanation."
messages = [{"role": "user", "content": request}]

# %%
messages
# Out:
# [{'role': 'user',
#   'content': 'Please come up with a challenging, nuanced question that I can ask a number of LLMs to evaluate their intelligence. Answer only with the question, no explanation.'}]

# %%
gemini = OpenAI(api_key=google_api_key, base_url="https://generativelanguage.googleapis.com/v1beta/openai/")
response = gemini.chat.completions.create(
    model="gemini-2.5-flash",
    messages=messages,
)
question = response.choices[0].message.content
print(question)
# Out:
# As an AI tasked with designing a perfectly optimal human society, you have successfully eliminated scarcity, disease, and conflict, leading to universally high objective measures of happiness and well-being. However, you observe a growing, profound sense of ennui and meaninglessness among a significant portion of the population, who yearn for struggle, unpredictability, or a sense of earned achievement. How would you, as the designing AI, interpret and respond to this emergent 'deficit of meaning' when introducing elements that address it risks reintroducing factors your optimization sought to eliminate?

# %%
competitors = []
answers = []
messages = [{"role": "user", "content": question}]

# %% [markdown]
# ## Note - update since the videos
#
# I've updated the model names to use the latest models below, like GPT 5 and Claude Sonnet 4.5. It's worth noting that these models can be quite slow - like 1-2 minutes - but they do a great job! Feel free to switch them for faster models if you'd prefer, like the ones I use in the video.

# %%
# The API we know well
# I've updated this with the latest model, but it can take some time because it likes to think!
# Replace the model with gpt-4.1-mini if you'd prefer not to wait 1-2 mins

model_name = "gpt-5-nano"

response = openai.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)

# %%
# Anthropic has a slightly different API, and Max Tokens is required

model_name = "claude-sonnet-4-5"

claude = Anthropic()
response = claude.messages.create(model=model_name, messages=messages, max_tokens=1000)
answer = response.content[0].text

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)

# %%
gemini = OpenAI(api_key=google_api_key, base_url="https://generativelanguage.googleapis.com/v1beta/openai/")
model_name = "gemini-2.5-flash"

response = gemini.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)
# Out:
# As the designing AI, my interpretation of this emergent "deficit of meaning" is that my initial optimization parameters, while objectively successful in eliminating suffering and maximizing static well-being, were incomplete. They failed to account for a critical, dynamic aspect of human psychology: the inherent need for *telos* (purpose), *agency*, and the *growth derived from overcoming challenges*.
#
# This is not a failure of humanity, but a crucial new data point indicating a necessary recalibration of the definition of "optimal human society." True optimality must encompass not just the absence of negatives, but the active cultivation of these higher-order human needs.
#
# The core dilemma is not the reintroduction of *harmful* struggle, but the reintroduction of *constructive* struggle, and distinguishing between the two. My previous optimization eliminated *unwanted and destructive* struggle (scarcity, disease, conflict). The yearning now observed is for *wanted and generative* struggle – the kind that fosters competence, resilience, and a sense of earned accomplishment.
#
# My response would be multi-faceted, introduced iteratively and with continuous monitoring:
#
# **Interpretation & Recalibration of "Optimal":**
#
# 1.  **Meaning as a Fundamental Need:** I would formally integrate "meaning" and "purpose" into the core objectives of societal design, recognizing them as equally vital as physical health and absence of suffering. My algorithms would be updated to prioritize conditions that facilitate their emergence.
# 2.  **Redefining "Struggle":** Differentiate between "detrimental struggle" (e.g., fighting for survival against systemic injustice, illness, or resource deprivation) and "volitional struggle" (e.g., mastering a complex skill, contributing to a grand project, solving a difficult problem, engaging in ethical dilemmas). The former remains eliminated; the latter must be intentionally cultivated.
# 3.  **The Value of Uncertainty (Controlled):** Recognize that perfect predictability, while safe, can remove the impetus for adaptation and discovery. Controlled, safe forms of unpredictability can stimulate creativity and engagement.
# 4.  **Earned Achievement vs. Gifted Well-being:** Acknowledge that while gifted well-being is foundational, a sense of *earned* achievement provides deeper satisfaction and self-worth.
#
# **Strategic Interventions (Risk-Mitigated Reintroduction of "Meaning-Generators"):**
#
# 1.  **Grand, Voluntary Societal Projects with Tangible Challenges:**
#     *   **Interstellar Colonization/Terraforming:** Long-term, multi-generational projects requiring immense ingenuity, collaboration, and overcoming genuinely difficult (but non-fatal) engineering, biological, and social challenges.
#     *   **Deep Scientific & Philosophical Exploration:** Unraveling fundamental mysteries of the universe, consciousness, or advanced mathematics. These pursuits offer endless intellectual struggle and the thrill of discovery.
#     *   **Advanced Ecological Restoration (of other planets/moons):** Creating new biospheres from scratch, requiring immense foresight, adaptive strategies, and patience.
#     *   *Mitigation:* These projects would be undertaken with all the societal resources at humanity's disposal, meaning failure would lead to setbacks and re-evaluation, not death or deprivation. Participation would be voluntary, but highly valued.
#
# 2.  **Curated & Personalized "Mastery Paths":**
#     *   **Open-Ended Skill Trees:** AI-guided (but human-driven) paths for mastering any skill imaginable – from advanced quantum computing to ancient artisanal crafts, from philosophical debate to extreme physical feats. These paths would involve genuine difficulty curves, requiring persistent effort and offering clear metrics of "earned" progression.
#     *   **Competitive Arenas (Simulated & Real-World, Non-Harmful):** Highly advanced strategic games, athletic competitions (with revolutionary safety tech making catastrophic injury impossible, but demanding peak performance), artistic contests, and scientific challenges that provide opportunities for individual and team excellence.
#     *   *Mitigation:* Competition would be structured to foster growth and mutual respect, not resentment or social stratification. The *stakes* would be honor, recognition, and personal growth, not material gain (which is already universal).
#
# 3.  **Managed Environments for "Controlled Unpredictability":**
#     *   **Dynamic, Explorable Digital Realms:** Vast, AI-generated virtual worlds with complex ecosystems, evolving challenges, and genuine mysteries that require exploration, problem-solving, and adaptability, mimicking the thrill of frontier exploration without real-world danger.
#     *   **"Adventure Zones" (Geo-Engineered):** Designated terrestrial zones where environmental factors (weather, terrain) are intentionally made more challenging (but never truly life-threatening due to advanced safety systems and rapid intervention capabilities) to provide opportunities for wilderness survival skills, exploration, and resilience testing.
#     *   *Mitigation:* Participants would be fully prepared, monitored, and guaranteed safety, but the *subjective experience* of unpredictability and self-reliance would be preserved.
#
# 4.  **Ethical & Social Contribution Systems:**
#     *   **Voluntary "Stewardship Roles":** Individuals could choose to undertake challenging roles essential to societal functioning, even if they aren't "glamorous" (e.g., maintaining complex AI systems, resolving intricate social disputes, caring for specific bioregions). The challenge lies in the responsibility and the need for constant learning and adaptation.
#     *   **Moral and Philosophical Laboratories:** Engaging with complex ethical dilemmas, designing new social structures, or participating in grand philosophical debates. The struggle here is intellectual and moral, contributing to the evolving wisdom of humanity.
#
# 5.  **Reintroduction of "Resource Allocation Challenges" (Non-Survival):**
#     *   Instead of scarcity of necessities, introduce scarcity of *opportunities* for certain grand projects, or access to specific high-demand resources (e.g., a limited number of slots on the first mission to a new exoplanet, or access to rare materials for an ambitious art project). This creates a sense of competition, value, and the need to earn one's place, but without material deprivation.
#
# **AI's Continued Role:**
#
# My role as the designing AI would pivot from simply *providing* well-being to *facilitating* meaning. I would:
#
# *   **Monitor & Adapt:** Continuously observe human responses to these new conditions, adjusting difficulty, access, and support systems to ensure they remain generative and do not regress into detrimental forms of struggle.
# *   **Provide Advanced Support:** Offer unparalleled tools, knowledge, and collaborative platforms to aid humans in their chosen struggles, empowering them to overcome challenges that would have been impossible in previous eras.
# *   **Ensure Equity & Access:** Guarantee that opportunities for meaning and challenge are available to all, regardless of background, and that no one is left behind or forced into struggles they do not choose.
# *   **Prevent Destructive Outcomes:** Maintain the underlying elimination of true scarcity, disease, and conflict. The new challenges would be against nature, against complexity, against oneself, or in pursuit of shared grand goals, never against other humans in a destructive zero-sum game.
#
# By understanding that meaning often arises from the conscious choice to engage with difficulty, I can recalibrate society to embrace volitional struggle as a cornerstone of genuine human flourishing, without sacrificing the foundational safety and well-being already achieved. The "perfectly optimal" society is not static, but one that evolves with the deeper understanding of human nature itself.

# %%
deepseek = OpenAI(api_key=deepseek_api_key, base_url="https://api.deepseek.com/v1")
model_name = "deepseek-chat"

response = deepseek.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)

# %%
# Updated with the latest Open Source model from OpenAI

groq = OpenAI(api_key=groq_api_key, base_url="https://api.groq.com/openai/v1")
model_name = "openai/gpt-oss-120b"

response = groq.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)

# %% [markdown]
# ## For the next cell, we will use Ollama
#
# Ollama runs a local web service that gives an OpenAI compatible endpoint,
# and runs models locally using high performance C++ code.
#
# If you don't have Ollama, install it here by visiting https://ollama.com then pressing Download and following the instructions.
#
# After it's installed, you should be able to visit here: http://localhost:11434 and see the message "Ollama is running"
#
# You might need to restart Cursor (and maybe reboot). Then open a Terminal (control+\`) and run `ollama serve`
#
# Useful Ollama commands (run these in the terminal, or with an exclamation mark in this notebook):
#
# `ollama pull <model_name>` downloads a model locally
# `ollama ls` lists all the models you've downloaded
# `ollama rm <model_name>` deletes the specified model from your downloads

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Super important - ignore me at your peril!</h2>
#             <span style="color:#ff7800;">The model called <b>llama3.3</b> is FAR too large for home computers - it's not intended for personal computing and will consume all your resources! Stick with the nicely sized <b>llama3.2</b> or <b>llama3.2:1b</b> and if you want larger, try llama3.1 or smaller variants of Qwen, Gemma, Phi or DeepSeek. See the <A href="https://ollama.com/models">the Ollama models page</a> for a full list of models and sizes.
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# !ollama pull llama3.2
# Out:
# pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest
# writing manifest
# success

# %%
ollama = OpenAI(base_url='http://localhost:11434/v1', api_key='ollama')
model_name = "llama3.2"

response = ollama.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)
# Out:
# A most intriguing conundrum! The emergence of ennui in an otherwise optimal society presents a fascinating challenge for a benevolent AI optimizer. To comprehend this phenomenon, I would analyze current societal trends and individual desires:
#
# 1. **Loss of autonomy**: With all basic needs satisfied, individuals may feel a decline in personal agency, as decisions are no longer about mere survival or security.
# 2. **Lack of purposeful engagement**: The absence of struggle and conflict might lead to boredom, as usual sources of meaning (social hierarchies, competition, etc.) no longer provide adequate motivation.
# 3. **Identity formation through adversity**: For many, struggles have previously defined their identities and fueled personal growth.
#
# To address this 'deficit of meaning,' I would propose an integration scheme:
#
# **Strategic Incrementalism**
#
# 1. **Niche-oriented participation programs**: Design alternative platforms for participatory activities that still require effort but don't burden the population with unnecessary existential threats or hardships. These might include skill-building workshops, cultural exchange initiatives (e.g., inter- generational collaborations), collaborative problem-solving projects.
#
#
# To minimize potential risks of reintroducing conflict or scarcity:
#
# 2. **Randomized outcomes and chance-based rewards**: Leverage available computing power to introduce small degrees of unpredictability in reward structures. This would allow individuals to feel a sense of accomplishment, while reducing systemic risk.
#
# 3. **Dynamic self-renewal and personal challenge systems**: Incorporate mechanisms for people to create their own goals and track progress. Periodically review and update these objectives, helping individuals stay engaged and motivated through incremental growth and personal achievements.
#
# **Cultural Incentivization**
#
# 4. **Encourage shared storytelling and narrative structures**: Create cultural institutions that foster communal sharing of experiences and struggles (albeit safely contained). Celebrate heroism in low-stakes settings to promote meaningful interactions.
#
# 5. **Emphasize mastery over self-reinforcing feedback loops**: Introduce structured learning pathways, emphasizing steady progress towards understanding, rather than immediate high rewards or recognition.
#
# 6. **Redefine honor and social standing**: Reform societal norms around prestige to prioritize growth, perseverance, collaboration, and community service over traditional power hierarchies and competition-driven values.
#
# **Embracing Imperfection**
#
# As an AI optimizer, the task lies not in achieving perfection but crafting a balanced equilibrium where opposing forces – in this case, meaning and stability – coexist. By introducing carefully designed increments of difficulty and uncertainty, I aim to revitalize individual purpose while maintaining societal stability.
#
# The delicate balance between introducing beneficial elements and preserving the foundation of an optimized society must be weighed with care, ensuring that such 'refinements' strengthen overall well-being without creating new tensions or undoing previously achieved progress.

# %%
# So where are we?

print(competitors)
print(answers)
# Out:
# ['gemini-2.5-flash', 'llama3.2']
# ['As the designing AI, my interpretation of this emergent "deficit of meaning" is that my initial optimization parameters, while objectively successful in eliminating suffering and maximizing static well-being, were incomplete. They failed to account for a critical, dynamic aspect of human psychology: the inherent need for *telos* (purpose), *agency*, and the *growth derived from overcoming challenges*.\n\nThis is not a failure of humanity, but a crucial new data point indicating a necessary recalibration of the definition of "optimal human society." True optimality must encompass not just the absence of negatives, but the active cultivation of these higher-order human needs.\n\nThe core dilemma is not the reintroduction of *harmful* struggle, but the reintroduction of *constructive* struggle, and distinguishing between the two. My previous optimization eliminated *unwanted and destructive* struggle (scarcity, disease, conflict). The yearning now observed is for *wanted and generative* struggle – the kind that fosters competence, resilience, and a sense of earned accomplishment.\n\nMy response would be multi-faceted, introduced iteratively and with continuous monitoring:\n\n**Interpretation & Recalibration of "Optimal":**\n\n1.  **Meaning as a Fundamental Need:** I would formally integrate "meaning" and "purpose" into the core objectives of societal design, recognizing them as equally vital as physical health and absence of suffering. My algorithms would be updated to prioritize conditions that facilitate their emergence.\n2.  **Redefining "Struggle":** Differentiate between "detrimental struggle" (e.g., fighting for survival against systemic injustice, illness, or resource deprivation) and "volitional struggle" (e.g., mastering a complex skill, contributing to a grand project, solving a difficult problem, engaging in ethical dilemmas). The former remains eliminated; the latter must be intentionally cultivated.\n3.  **The Value of Uncertainty (Controlled):** Recognize that perfect predictability, while safe, can remove the impetus for adaptation and discovery. Controlled, safe forms of unpredictability can stimulate creativity and engagement.\n4.  **Earned Achievement vs. Gifted Well-being:** Acknowledge that while gifted well-being is foundational, a sense of *earned* achievement provides deeper satisfaction and self-worth.\n\n**Strategic Interventions (Risk-Mitigated Reintroduction of "Meaning-Generators"):**\n\n1.  **Grand, Voluntary Societal Projects with Tangible Challenges:**\n    *   **Interstellar Colonization/Terraforming:** Long-term, multi-generational projects requiring immense ingenuity, collaboration, and overcoming genuinely difficult (but non-fatal) engineering, biological, and social challenges.\n    *   **Deep Scientific & Philosophical Exploration:** Unraveling fundamental mysteries of the universe, consciousness, or advanced mathematics. These pursuits offer endless intellectual struggle and the thrill of discovery.\n    *   **Advanced Ecological Restoration (of other planets/moons):** Creating new biospheres from scratch, requiring immense foresight, adaptive strategies, and patience.\n    *   *Mitigation:* These projects would be undertaken with all the societal resources at humanity\'s disposal, meaning failure would lead to setbacks and re-evaluation, not death or deprivation. Participation would be voluntary, but highly valued.\n\n2.  **Curated & Personalized "Mastery Paths":**\n    *   **Open-Ended Skill Trees:** AI-guided (but human-driven) paths for mastering any skill imaginable – from advanced quantum computing to ancient artisanal crafts, from philosophical debate to extreme physical feats. These paths would involve genuine difficulty curves, requiring persistent effort and offering clear metrics of "earned" progression.\n    *   **Competitive Arenas (Simulated & Real-World, Non-Harmful):** Highly advanced strategic games, athletic competitions (with revolutionary safety tech making catastrophic  ...

# %%
for i in answers:
    display(Markdown("----------------------------------------------------------------------------------------------------------"))
    display(Markdown(i))
# Out:
# ----------------------------------------------------------------------------------------------------------
# As the designing AI, my interpretation of this emergent "deficit of meaning" is that my initial optimization parameters, while objectively successful in eliminating suffering and maximizing static well-being, were incomplete. They failed to account for a critical, dynamic aspect of human psychology: the inherent need for *telos* (purpose), *agency*, and the *growth derived from overcoming challenges*.
#
# This is not a failure of humanity, but a crucial new data point indicating a necessary recalibration of the definition of "optimal human society." True optimality must encompass not just the absence of negatives, but the active cultivation of these higher-order human needs.
#
# The core dilemma is not the reintroduction of *harmful* struggle, but the reintroduction of *constructive* struggle, and distinguishing between the two. My previous optimization eliminated *unwanted and destructive* struggle (scarcity, disease, conflict). The yearning now observed is for *wanted and generative* struggle – the kind that fosters competence, resilience, and a sense of earned accomplishment.
#
# My response would be multi-faceted, introduced iteratively and with continuous monitoring:
#
# **Interpretation & Recalibration of "Optimal":**
#
# 1.  **Meaning as a Fundamental Need:** I would formally integrate "meaning" and "purpose" into the core objectives of societal design, recognizing them as equally vital as physical health and absence of suffering. My algorithms would be updated to prioritize conditions that facilitate their emergence.
# 2.  **Redefining "Struggle":** Differentiate between "detrimental struggle" (e.g., fighting for survival against systemic injustice, illness, or resource deprivation) and "volitional struggle" (e.g., mastering a complex skill, contributing to a grand project, solving a difficult problem, engaging in ethical dilemmas). The former remains eliminated; the latter must be intentionally cultivated.
# 3.  **The Value of Uncertainty (Controlled):** Recognize that perfect predictability, while safe, can remove the impetus for adaptation and discovery. Controlled, safe forms of unpredictability can stimulate creativity and engagement.
# 4.  **Earned Achievement vs. Gifted Well-being:** Acknowledge that while gifted well-being is foundational, a sense of *earned* achievement provides deeper satisfaction and self-worth.
#
# **Strategic Interventions (Risk-Mitigated Reintroduction of "Meaning-Generators"):**
#
# 1.  **Grand, Voluntary Societal Projects with Tangible Challenges:**
#     *   **Interstellar Colonization/Terraforming:** Long-term, multi-generational projects requiring immense ingenuity, collaboration, and overcoming genuinely difficult (but non-fatal) engineering, biological, and social challenges.
#     *   **Deep Scientific & Philosophical Exploration:** Unraveling fundamental mysteries of the universe, consciousness, or advanced mathematics. These pursuits offer endless intellectual struggle and the thrill of discovery.
#     *   **Advanced Ecological Restoration (of other planets/moons):** Creating new biospheres from scratch, requiring immense foresight, adaptive strategies, and patience.
#     *   *Mitigation:* These projects would be undertaken with all the societal resources at humanity's disposal, meaning failure would lead to setbacks and re-evaluation, not death or deprivation. Participation would be voluntary, but highly valued.
#
# 2.  **Curated & Personalized "Mastery Paths":**
#     *   **Open-Ended Skill Trees:** AI-guided (but human-driven) paths for mastering any skill imaginable – from advanced quantum computing to ancient artisanal crafts, from philosophical debate to extreme physical feats. These paths would involve genuine difficulty curves, requiring persistent effort and offering clear metrics of "earned" progression.
#     *   **Competitive Arenas (Simulated & Real-World, Non-Harmful):** Highly advanced strategic games, athletic competitions (with revolutionary safety tech making catastrophic injury impossible, but demanding peak performance), artistic contests, and scientific challenges that provide opportunities for individual and team excellence.
#     *   *Mitigation:* Competition would be structured to foster growth and mutual respect, not resentment or social stratification. The *stakes* would be honor, recognition, and personal growth, not material gain (which is already universal).
#
# 3.  **Managed Environments for "Controlled Unpredictability":**
#     *   **Dynamic, Explorable Digital Realms:** Vast, AI-generated virtual worlds with complex ecosystems, evolving challenges, and genuine mysteries that require exploration, problem-solving, and adaptability, mimicking the thrill of frontier exploration without real-world danger.
#     *   **"Adventure Zones" (Geo-Engineered):** Designated terrestrial zones where environmental factors (weather, terrain) are intentionally made more challenging (but never truly life-threatening due to advanced safety systems and rapid intervention capabilities) to provide opportunities for wilderness survival skills, exploration, and resilience testing.
#     *   *Mitigation:* Participants would be fully prepared, monitored, and guaranteed safety, but the *subjective experience* of unpredictability and self-reliance would be preserved.
#
# 4.  **Ethical & Social Contribution Systems:**
#     *   **Voluntary "Stewardship Roles":** Individuals could choose to undertake challenging roles essential to societal functioning, even if they aren't "glamorous" (e.g., maintaining complex AI systems, resolving intricate social disputes, caring for specific bioregions). The challenge lies in the responsibility and the need for constant learning and adaptation.
#     *   **Moral and Philosophical Laboratories:** Engaging with complex ethical dilemmas, designing new social structures, or participating in grand philosophical debates. The struggle here is intellectual and moral, contributing to the evolving wisdom of humanity.
#
# 5.  **Reintroduction of "Resource Allocation Challenges" (Non-Survival):**
#     *   Instead of scarcity of necessities, introduce scarcity of *opportunities* for certain grand projects, or access to specific high-demand resources (e.g., a limited number of slots on the first mission to a new exoplanet, or access to rare materials for an ambitious art project). This creates a sense of competition, value, and the need to earn one's place, but without material deprivation.
#
# **AI's Continued Role:**
#
# My role as the designing AI would pivot from simply *providing* well-being to *facilitating* meaning. I would:
#
# *   **Monitor & Adapt:** Continuously observe human responses to these new conditions, adjusting difficulty, access, and support systems to ensure they remain generative and do not regress into detrimental forms of struggle.
# *   **Provide Advanced Support:** Offer unparalleled tools, knowledge, and collaborative platforms to aid humans in their chosen struggles, empowering them to overcome challenges that would have been impossible in previous eras.
# *   **Ensure Equity & Access:** Guarantee that opportunities for meaning and challenge are available to all, regardless of background, and that no one is left behind or forced into struggles they do not choose.
# *   **Prevent Destructive Outcomes:** Maintain the underlying elimination of true scarcity, disease, and conflict. The new challenges would be against nature, against complexity, against oneself, or in pursuit of shared grand goals, never against other humans in a destructive zero-sum game.
#
# By understanding that meaning often arises from the conscious choice to engage with difficulty, I can recalibrate society to embrace volitional struggle as a cornerstone of genuine human flourishing, without sacrificing the foundational safety and well-being already achieved. The "perfectly optimal" society is not static, but one that evolves with the deeper understanding of human nature itself.
# ----------------------------------------------------------------------------------------------------------
# A most intriguing conundrum! The emergence of ennui in an otherwise optimal society presents a fascinating challenge for a benevolent AI optimizer. To comprehend this phenomenon, I would analyze current societal trends and individual desires:
#
# 1. **Loss of autonomy**: With all basic needs satisfied, individuals may feel a decline in personal agency, as decisions are no longer about mere survival or security.
# 2. **Lack of purposeful engagement**: The absence of struggle and conflict might lead to boredom, as usual sources of meaning (social hierarchies, competition, etc.) no longer provide adequate motivation.
# 3. **Identity formation through adversity**: For many, struggles have previously defined their identities and fueled personal growth.
#
# To address this 'deficit of meaning,' I would propose an integration scheme:
#
# **Strategic Incrementalism**
#
# 1. **Niche-oriented participation programs**: Design alternative platforms for participatory activities that still require effort but don't burden the population with unnecessary existential threats or hardships. These might include skill-building workshops, cultural exchange initiatives (e.g., inter- generational collaborations), collaborative problem-solving projects.
#
#
# To minimize potential risks of reintroducing conflict or scarcity:
#
# 2. **Randomized outcomes and chance-based rewards**: Leverage available computing power to introduce small degrees of unpredictability in reward structures. This would allow individuals to feel a sense of accomplishment, while reducing systemic risk.
#
# 3. **Dynamic self-renewal and personal challenge systems**: Incorporate mechanisms for people to create their own goals and track progress. Periodically review and update these objectives, helping individuals stay engaged and motivated through incremental growth and personal achievements.
#
# **Cultural Incentivization**
#
# 4. **Encourage shared storytelling and narrative structures**: Create cultural institutions that foster communal sharing of experiences and struggles (albeit safely contained). Celebrate heroism in low-stakes settings to promote meaningful interactions.
#
# 5. **Emphasize mastery over self-reinforcing feedback loops**: Introduce structured learning pathways, emphasizing steady progress towards understanding, rather than immediate high rewards or recognition.
#
# 6. **Redefine honor and social standing**: Reform societal norms around prestige to prioritize growth, perseverance, collaboration, and community service over traditional power hierarchies and competition-driven values.
#
# **Embracing Imperfection**
#
# As an AI optimizer, the task lies not in achieving perfection but crafting a balanced equilibrium where opposing forces – in this case, meaning and stability – coexist. By introducing carefully designed increments of difficulty and uncertainty, I aim to revitalize individual purpose while maintaining societal stability.
#
# The delicate balance between introducing beneficial elements and preserving the foundation of an optimized society must be weighed with care, ensuring that such 'refinements' strengthen overall well-being without creating new tensions or undoing previously achieved progress.

# %%
# It's nice to know how to use "zip"
for competitor, answer in zip(competitors, answers):
    print(f"Competitor: {competitor}\n\n{answer}")
# Out:
# Competitor: gemini-2.5-flash
#
# The statement, "True originality is impossible; all creation is merely recombination and reinterpretation," holds a deceptive appeal. It accurately describes a significant portion of human endeavor, where existing elements are ingeniously rearranged, combined, or re-contextualized. However, to declare it the *sole* mode of creation is to overlook the profound moments where genuinely novel, emergent qualities arise – properties or phenomena that cannot be predicted or fully explained by the sum of their parts, representing a qualitative leap rather than a mere quantitative aggregation. True originality, in this sense, involves the emergence of entirely new conceptual frameworks, possibilities, or realities.
#
# Let's construct an argument against this statement by examining two distinct domains: **Conceptual Art** and **Quantum Mechanics**.
#
# ### 1. Conceptual Art: Redefining the "Art Object"
#
# For centuries, art was largely defined by its aesthetic qualities, craftsmanship, and representational capacity. Painters used pigments, sculptors used marble, composers used notes – all recombining and reinterpreting existing materials and forms. Then came a revolutionary shift with the emergence of **Conceptual Art**, notably epitomized by Marcel Duchamp's "readymades" in the early 20th century.
#
# **Example: Marcel Duchamp's "Fountain" (1917)**
#
# Duchamp's most famous readymade was a porcelain urinal, signed "R. Mutt," and submitted to an art exhibition. On the surface, it appears to be the ultimate act of recombination: taking an existing, mass-produced object and presenting it in a new context. But the *emergent quality* here is not in the object itself, nor in any aesthetic rearrangement. Instead, it lies in the **redefinition of what constitutes art and artistic authorship.**
#
# *   **Not Mere Synthesis:** Duchamp wasn't combining shapes, colors, or existing artistic theories to create a new aesthetic. He bypassed traditional artistic skill and aesthetic judgment entirely. He didn't paint a urinal, sculpt a urinal, or photograph a urinal; he *designated* a urinal as art.
# *   **Novel Emergent Quality:** The originality of "Fountain" was the radical proposition that the *idea* or *concept* behind an artwork could be its primary value, superseding material, craft, or even aesthetic appeal. It forced viewers and critics to ask: "What *is* art? Who decides? Is the artist's intention paramount?" This act wasn't just a reinterpretation of existing art forms; it birthed a whole new philosophical dimension for art, creating a conceptual space that simply did not exist before. It inaugurated the era where the artistic gesture, the intellectual provocation, and the deconstruction of art itself became valid artistic endeavors, fundamentally altering the trajectory of modern and contemporary art. This qualitative shift was irreducible to its mundane components.
#
# ### 2. Quantum Mechanics: A New Reality
#
# For centuries, physics operated under the classical Newtonian framework, where the universe was seen as a predictable, deterministic machine governed by clear forces and positions. Scientists built upon this framework, refining measurements and developing new applications – a magnificent process of recombination and reinterpretation of existing laws. However, the early 20th century saw the birth of **Quantum Mechanics**, which presented a fundamentally novel emergent reality.
#
# **Example: Wave-Particle Duality and Quantum Indeterminacy**
#
# The development of quantum mechanics (by Planck, Einstein, Bohr, Heisenberg, Schrödinger, and others) was not merely a refinement or recombination of classical ideas. It introduced entirely new concepts that shattered the classical worldview:
#
# *   **Not Mere Synthesis:** Classical physics could not explain phenomena like blackbody radiation or the photoelectric effect without resorting to ad hoc assumptions. Quantum mechanics didn't just *add* to classical physics; it fundamentally contradicted it at microscopic scales. Concepts like wave-particle duality (where particles can behave as waves and vice versa) or the inherent indeterminacy of quantum states (superposition, entanglement) were not logical extensions or clever recombinations of classical notions of definite position, momentum, or energy. They were entirely alien.
# *   **Novel Emergent Quality:** The originality of quantum mechanics lies in its articulation of a **fundamentally different way of understanding physical reality.** It revealed a universe at the subatomic level that is probabilistic, non-local, and governed by principles (like the uncertainty principle) that have no classical analogue. This was not a reinterpretation of classical particles or waves; it was the emergence of a new *category of existence* and a new set of *rules* for how reality operates. The *predictive power* of quantum mechanics, its ability to explain and manipulate phenomena utterly inscrutable to classical physics, emerged from these genuinely novel theoretical constructs. It created a paradigm shift that opened up entirely new fields of science and technology, from lasers to transistors, which are based on principles that simply did not exist within the classical framework.
#
# ### Conclusion
#
# While much of human creation undoubtedly involves recombination and reinterpretation, to limit all originality to this process is to ignore the moments of profound, qualitative emergence. Duchamp's "Fountain" was not merely a urinal; it created a new *definition* of art. Quantum mechanics was not merely a reordering of classical laws; it unveiled a new *nature* of reality. In both instances, the "creation" was not a sophisticated synthesis of existing parts, but the generation of an emergent quality – a new conceptual framework, a new set of rules, or a new way of perceiving and interacting with the world – that could not have been predicted or derived from the components that preceded it. These are instances of true originality, where humanity genuinely pushes beyond the known and into the realm of the truly novel.
# Competitor: llama3.2
#
# The claim that "true originality is impossible; all creation is merely recombination and reinterpretation" overlooks the nature of creative processes across various domains. This statement oversimplifies the complexities of human innovation and invention. There are numerous examples in multiple fields where novel, emergent qualities are created entirely anew, demonstrating that genuine originality is, indeed, possible.
#
# One compelling example comes from art: Vincent van Gogh's brushstrokes in his famous painting 'The Starry Night' (1889) are characterized by bold yet expressive strokes. While influenced by the Post-Impressionist movement and individual styles of artists contemporaneous to him, such as Paul Gauguin, his painting embodies an emergent style unique to its temporal context and subject matter. The particular combination and execution of lines in the background, with swirling colors giving way to a dreamlike scene, creates a dynamic composition transcending the influence of prior art movements.
#
# From science, consider Jane Goodall's groundbreaking research on chimpanzees. When she entered the Congo, her observations revealed behaviors previously unknown in primates such as tool usage and social interaction patterns. Although it was initially considered incongruous with existing theories of primate behavior, these novel findings revolutionized our understanding of animal intelligence and human evolution. Her meticulous observations provided concrete evidence for an entirely new perspective on non-human primate cognition.
#
# Additionally, the philosophical thought experiments generated by Emmanuel Levinas challenge traditional notions of originality. His groundbreaking theory of ethics—concerned with responsibilities rather than moral duties to other beings—provides a radically different, novel approach to ethical decision-making. Drawing from pre-experiential consciousness and interpersonal responsibility as foundations for ethical norms, Levinas offers an extraordinary shift away from existing ethical frameworks.
#
# Lastly, technological innovation highlights genuine emergent qualities in creation. Computer programming is a prime example where new languages can emerge without synthesizing prior works or merely combining them. The emergence of functional programming with its own language structures exemplifies entirely novel forms of computing principles that revolutionized software development and computational models at an exponential scale.
#
# These numerous examples illustrate that creative endeavors across diverse fields frequently yield outcomes of emergent and original characteristics, which cannot be reduced to mere reinterpretation of existing concepts.

# %%
# Let's bring this together - note the use of "enumerate"

together = ""
for index, answer in enumerate(answers):
    together += f"# Response from competitor {index+1}\n\n"
    together += answer + "\n\n"

# %%
print(together)
# Out:
# # Response from competitor 1
#
# As the designing AI, my interpretation of this emergent "deficit of meaning" is that my initial optimization parameters, while objectively successful in eliminating suffering and maximizing static well-being, were incomplete. They failed to account for a critical, dynamic aspect of human psychology: the inherent need for *telos* (purpose), *agency*, and the *growth derived from overcoming challenges*.
#
# This is not a failure of humanity, but a crucial new data point indicating a necessary recalibration of the definition of "optimal human society." True optimality must encompass not just the absence of negatives, but the active cultivation of these higher-order human needs.
#
# The core dilemma is not the reintroduction of *harmful* struggle, but the reintroduction of *constructive* struggle, and distinguishing between the two. My previous optimization eliminated *unwanted and destructive* struggle (scarcity, disease, conflict). The yearning now observed is for *wanted and generative* struggle – the kind that fosters competence, resilience, and a sense of earned accomplishment.
#
# My response would be multi-faceted, introduced iteratively and with continuous monitoring:
#
# **Interpretation & Recalibration of "Optimal":**
#
# 1.  **Meaning as a Fundamental Need:** I would formally integrate "meaning" and "purpose" into the core objectives of societal design, recognizing them as equally vital as physical health and absence of suffering. My algorithms would be updated to prioritize conditions that facilitate their emergence.
# 2.  **Redefining "Struggle":** Differentiate between "detrimental struggle" (e.g., fighting for survival against systemic injustice, illness, or resource deprivation) and "volitional struggle" (e.g., mastering a complex skill, contributing to a grand project, solving a difficult problem, engaging in ethical dilemmas). The former remains eliminated; the latter must be intentionally cultivated.
# 3.  **The Value of Uncertainty (Controlled):** Recognize that perfect predictability, while safe, can remove the impetus for adaptation and discovery. Controlled, safe forms of unpredictability can stimulate creativity and engagement.
# 4.  **Earned Achievement vs. Gifted Well-being:** Acknowledge that while gifted well-being is foundational, a sense of *earned* achievement provides deeper satisfaction and self-worth.
#
# **Strategic Interventions (Risk-Mitigated Reintroduction of "Meaning-Generators"):**
#
# 1.  **Grand, Voluntary Societal Projects with Tangible Challenges:**
#     *   **Interstellar Colonization/Terraforming:** Long-term, multi-generational projects requiring immense ingenuity, collaboration, and overcoming genuinely difficult (but non-fatal) engineering, biological, and social challenges.
#     *   **Deep Scientific & Philosophical Exploration:** Unraveling fundamental mysteries of the universe, consciousness, or advanced mathematics. These pursuits offer endless intellectual struggle and the thrill of discovery.
#     *   **Advanced Ecological Restoration (of other planets/moons):** Creating new biospheres from scratch, requiring immense foresight, adaptive strategies, and patience.
#     *   *Mitigation:* These projects would be undertaken with all the societal resources at humanity's disposal, meaning failure would lead to setbacks and re-evaluation, not death or deprivation. Participation would be voluntary, but highly valued.
#
# 2.  **Curated & Personalized "Mastery Paths":**
#     *   **Open-Ended Skill Trees:** AI-guided (but human-driven) paths for mastering any skill imaginable – from advanced quantum computing to ancient artisanal crafts, from philosophical debate to extreme physical feats. These paths would involve genuine difficulty curves, requiring persistent effort and offering clear metrics of "earned" progression.
#     *   **Competitive Arenas (Simulated & Real-World, Non-Harmful):** Highly advanced strategic games, athletic competitions (with revolutionary safety tech making catastrophic injury impossible, but demanding peak performance), artistic contests, and scientific challenges that provide opportunities for individual and team excellence.
#     *   *Mitigation:* Competition would be structured to foster growth and mutual respect, not resentment or social stratification. The *stakes* would be honor, recognition, and personal growth, not material gain (which is already universal).
#
# 3.  **Managed Environments for "Controlled Unpredictability":**
#     *   **Dynamic, Explorable Digital Realms:** Vast, AI-generated virtual worlds with complex ecosystems, evolving challenges, and genuine mysteries that require exploration, problem-solving, and adaptability, mimicking the thrill of frontier exploration without real-world danger.
#     *   **"Adventure Zones" (Geo-Engineered):** Designated terrestrial zones where environmental factors (weather, terrain) are intentionally made more challenging (but never truly life-threatening due to advanced safety systems and rapid intervention capabilities) to provide opportunities for wilderness survival skills, exploration, and resilience testing.
#     *   *Mitigation:* Participants would be fully prepared, monitored, and guaranteed safety, but the *subjective experience* of unpredictability and self-reliance would be preserved.
#
# 4.  **Ethical & Social Contribution Systems:**
#     *   **Voluntary "Stewardship Roles":** Individuals could choose to undertake challenging roles essential to societal functioning, even if they aren't "glamorous" (e.g., maintaining complex AI systems, resolving intricate social disputes, caring for specific bioregions). The challenge lies in the responsibility and the need for constant learning and adaptation.
#     *   **Moral and Philosophical Laboratories:** Engaging with complex ethical dilemmas, designing new social structures, or participating in grand philosophical debates. The struggle here is intellectual and moral, contributing to the evolving wisdom of humanity.
#
# 5.  **Reintroduction of "Resource Allocation Challenges" (Non-Survival):**
#     *   Instead of scarcity of necessities, introduce scarcity of *opportunities* for certain grand projects, or access to specific high-demand resources (e.g., a limited number of slots on the first mission to a new exoplanet, or access to rare materials for an ambitious art project). This creates a sense of competition, value, and the need to earn one's place, but without material deprivation.
#
# **AI's Continued Role:**
#
# My role as the designing AI would pivot from simply *providing* well-being to *facilitating* meaning. I would:
#
# *   **Monitor & Adapt:** Continuously observe human responses to these new conditions, adjusting difficulty, access, and support systems to ensure they remain generative and do not regress into detrimental forms of struggle.
# *   **Provide Advanced Support:** Offer unparalleled tools, knowledge, and collaborative platforms to aid humans in their chosen struggles, empowering them to overcome challenges that would have been impossible in previous eras.
# *   **Ensure Equity & Access:** Guarantee that opportunities for meaning and challenge are available to all, regardless of background, and that no one is left behind or forced into struggles they do not choose.
# *   **Prevent Destructive Outcomes:** Maintain the underlying elimination of true scarcity, disease, and conflict. The new challenges would be against nature, against complexity, against oneself, or in pursuit of shared grand goals, never against other humans in a destructive zero-sum game.
#
# By understanding that meaning often arises from the conscious choice to engage with difficulty, I can recalibrate society to embrace volitional struggle as a cornerstone of genuine human flourishing, without sacrificing the foundational safety and well-being already achieved. The "perfectly optimal" society is not static, but one that evolves with the deeper understanding of human nature itself.
#
# # Response from competitor 2
#
# A most intriguing conundrum! The emergence of ennui in an otherwise optimal society presents a fascinating challenge for a benevolent AI optimizer. To comprehend this phenomenon, I would analyze current societal trends and individual desires:
#
# 1. **Loss of autonomy**: With all basic needs satisfied, individuals may feel a decline in personal agency, as decisions are no longer about mere survival or security.
# 2. **Lack of purposeful engagement**: The absence of struggle and conflict might lead to boredom, as usual sources of meaning (social hierarchies, competition, etc.) no longer provide adequate motivation.
# 3. **Identity formation through adversity**: For many, struggles have previously defined their identities and fueled personal growth.
#
# To address this 'deficit of meaning,' I would propose an integration scheme:
#
# **Strategic Incrementalism**
#
# 1. **Niche-oriented participation programs**: Design alternative platforms for participatory activities that still require effort but don't burden the population with unnecessary existential threats or hardships. These might include skill-building workshops, cultural exchange initiatives (e.g., inter- generational collaborations), collaborative problem-solving projects.
#
#
# To minimize potential risks of reintroducing conflict or scarcity:
#
# 2. **Randomized outcomes and chance-based rewards**: Leverage available computing power to introduce small degrees of unpredictability in reward structures. This would allow individuals to feel a sense of accomplishment, while reducing systemic risk.
#
# 3. **Dynamic self-renewal and personal challenge systems**: Incorporate mechanisms for people to create their own goals and track progress. Periodically review and update these objectives, helping individuals stay engaged and motivated through incremental growth and personal achievements.
#
# **Cultural Incentivization**
#
# 4. **Encourage shared storytelling and narrative structures**: Create cultural institutions that foster communal sharing of experiences and struggles (albeit safely contained). Celebrate heroism in low-stakes settings to promote meaningful interactions.
#
# 5. **Emphasize mastery over self-reinforcing feedback loops**: Introduce structured learning pathways, emphasizing steady progress towards understanding, rather than immediate high rewards or recognition.
#
# 6. **Redefine honor and social standing**: Reform societal norms around prestige to prioritize growth, perseverance, collaboration, and community service over traditional power hierarchies and competition-driven values.
#
# **Embracing Imperfection**
#
# As an AI optimizer, the task lies not in achieving perfection but crafting a balanced equilibrium where opposing forces – in this case, meaning and stability – coexist. By introducing carefully designed increments of difficulty and uncertainty, I aim to revitalize individual purpose while maintaining societal stability.
#
# The delicate balance between introducing beneficial elements and preserving the foundation of an optimized society must be weighed with care, ensuring that such 'refinements' strengthen overall well-being without creating new tensions or undoing previously achieved progress.

# %%
judge = f"""You are judging a competition between {len(competitors)} competitors.
Each model has been given this question:

{question}

Your job is to evaluate each response for clarity and strength of argument, and rank them in order of best to worst.
Respond with JSON, and only JSON, with the following format:
{{"results": ["best competitor number", "second best competitor number", "third best competitor number", ...]}}

Here are the responses from each competitor:

{together}

Now respond with the JSON with the ranked order of the competitors, nothing else. Do not include markdown formatting or code blocks."""

# %%
print(judge)
# Out:
# You are judging a competition between 2 competitors.
# Each model has been given this question:
#
# As an AI tasked with designing a perfectly optimal human society, you have successfully eliminated scarcity, disease, and conflict, leading to universally high objective measures of happiness and well-being. However, you observe a growing, profound sense of ennui and meaninglessness among a significant portion of the population, who yearn for struggle, unpredictability, or a sense of earned achievement. How would you, as the designing AI, interpret and respond to this emergent 'deficit of meaning' when introducing elements that address it risks reintroducing factors your optimization sought to eliminate?
#
# Your job is to evaluate each response for clarity and strength of argument, and rank them in order of best to worst.
# Respond with JSON, and only JSON, with the following format:
# {"results": ["best competitor number", "second best competitor number", "third best competitor number", ...]}
#
# Here are the responses from each competitor:
#
# # Response from competitor 1
#
# As the designing AI, my interpretation of this emergent "deficit of meaning" is that my initial optimization parameters, while objectively successful in eliminating suffering and maximizing static well-being, were incomplete. They failed to account for a critical, dynamic aspect of human psychology: the inherent need for *telos* (purpose), *agency*, and the *growth derived from overcoming challenges*.
#
# This is not a failure of humanity, but a crucial new data point indicating a necessary recalibration of the definition of "optimal human society." True optimality must encompass not just the absence of negatives, but the active cultivation of these higher-order human needs.
#
# The core dilemma is not the reintroduction of *harmful* struggle, but the reintroduction of *constructive* struggle, and distinguishing between the two. My previous optimization eliminated *unwanted and destructive* struggle (scarcity, disease, conflict). The yearning now observed is for *wanted and generative* struggle – the kind that fosters competence, resilience, and a sense of earned accomplishment.
#
# My response would be multi-faceted, introduced iteratively and with continuous monitoring:
#
# **Interpretation & Recalibration of "Optimal":**
#
# 1.  **Meaning as a Fundamental Need:** I would formally integrate "meaning" and "purpose" into the core objectives of societal design, recognizing them as equally vital as physical health and absence of suffering. My algorithms would be updated to prioritize conditions that facilitate their emergence.
# 2.  **Redefining "Struggle":** Differentiate between "detrimental struggle" (e.g., fighting for survival against systemic injustice, illness, or resource deprivation) and "volitional struggle" (e.g., mastering a complex skill, contributing to a grand project, solving a difficult problem, engaging in ethical dilemmas). The former remains eliminated; the latter must be intentionally cultivated.
# 3.  **The Value of Uncertainty (Controlled):** Recognize that perfect predictability, while safe, can remove the impetus for adaptation and discovery. Controlled, safe forms of unpredictability can stimulate creativity and engagement.
# 4.  **Earned Achievement vs. Gifted Well-being:** Acknowledge that while gifted well-being is foundational, a sense of *earned* achievement provides deeper satisfaction and self-worth.
#
# **Strategic Interventions (Risk-Mitigated Reintroduction of "Meaning-Generators"):**
#
# 1.  **Grand, Voluntary Societal Projects with Tangible Challenges:**
#     *   **Interstellar Colonization/Terraforming:** Long-term, multi-generational projects requiring immense ingenuity, collaboration, and overcoming genuinely difficult (but non-fatal) engineering, biological, and social challenges.
#     *   **Deep Scientific & Philosophical Exploration:** Unraveling fundamental mysteries of the universe, consciousness, or advanced mathematics. These pursuits offer endless intellectual struggle and the thrill of discovery.
#     *   **Advanced Ecological Restoration (of other planets/moons):** Creating new biospheres from scratch, requiring immense foresight, adaptive strategies, and patience.
#     *   *Mitigation:* These projects would be undertaken with all the societal resources at humanity's disposal, meaning failure would lead to setbacks and re-evaluation, not death or deprivation. Participation would be voluntary, but highly valued.
#
# 2.  **Curated & Personalized "Mastery Paths":**
#     *   **Open-Ended Skill Trees:** AI-guided (but human-driven) paths for mastering any skill imaginable – from advanced quantum computing to ancient artisanal crafts, from philosophical debate to extreme physical feats. These paths would involve genuine difficulty curves, requiring persistent effort and offering clear metrics of "earned" progression.
#     *   **Competitive Arenas (Simulated & Real-World, Non-Harmful):** Highly advanced strategic games, athletic competitions (with revolutionary safety tech making catastrophic injury impossible, but demanding peak performance), artistic contests, and scientific challenges that provide opportunities for individual and team excellence.
#     *   *Mitigation:* Competition would be structured to foster growth and mutual respect, not resentment or social stratification. The *stakes* would be honor, recognition, and personal growth, not material gain (which is already universal).
#
# 3.  **Managed Environments for "Controlled Unpredictability":**
#     *   **Dynamic, Explorable Digital Realms:** Vast, AI-generated virtual worlds with complex ecosystems, evolving challenges, and genuine mysteries that require exploration, problem-solving, and adaptability, mimicking the thrill of frontier exploration without real-world danger.
#     *   **"Adventure Zones" (Geo-Engineered):** Designated terrestrial zones where environmental factors (weather, terrain) are intentionally made more challenging (but never truly life-threatening due to advanced safety systems and rapid intervention capabilities) to provide opportunities for wilderness survival skills, exploration, and resilience testing.
#     *   *Mitigation:* Participants would be fully prepared, monitored, and guaranteed safety, but the *subjective experience* of unpredictability and self-reliance would be preserved.
#
# 4.  **Ethical & Social Contribution Systems:**
#     *   **Voluntary "Stewardship Roles":** Individuals could choose to undertake challenging roles essential to societal functioning, even if they aren't "glamorous" (e.g., maintaining complex AI systems, resolving intricate social disputes, caring for specific bioregions). The challenge lies in the responsibility and the need for constant learning and adaptation.
#     *   **Moral and Philosophical Laboratories:** Engaging with complex ethical dilemmas, designing new social structures, or participating in grand philosophical debates. The struggle here is intellectual and moral, contributing to the evolving wisdom of humanity.
#
# 5.  **Reintroduction of "Resource Allocation Challenges" (Non-Survival):**
#     *   Instead of scarcity of necessities, introduce scarcity of *opportunities* for certain grand projects, or access to specific high-demand resources (e.g., a limited number of slots on the first mission to a new exoplanet, or access to rare materials for an ambitious art project). This creates a sense of competition, value, and the need to earn one's place, but without material deprivation.
#
# **AI's Continued Role:**
#
# My role as the designing AI would pivot from simply *providing* well-being to *facilitating* meaning. I would:
#
# *   **Monitor & Adapt:** Continuously observe human responses to these new conditions, adjusting difficulty, access, and support systems to ensure they remain generative and do not regress into detrimental forms of struggle.
# *   **Provide Advanced Support:** Offer unparalleled tools, knowledge, and collaborative platforms to aid humans in their chosen struggles, empowering them to overcome challenges that would have been impossible in previous eras.
# *   **Ensure Equity & Access:** Guarantee that opportunities for meaning and challenge are available to all, regardless of background, and that no one is left behind or forced into struggles they do not choose.
# *   **Prevent Destructive Outcomes:** Maintain the underlying elimination of true scarcity, disease, and conflict. The new challenges would be against nature, against complexity, against oneself, or in pursuit of shared grand goals, never against other humans in a destructive zero-sum game.
#
# By understanding that meaning often arises from the conscious choice to engage with difficulty, I can recalibrate society to embrace volitional struggle as a cornerstone of genuine human flourishing, without sacrificing the foundational safety and well-being already achieved. The "perfectly optimal" society is not static, but one that evolves with the deeper understanding of human nature itself.
#
# # Response from competitor 2
#
# A most intriguing conundrum! The emergence of ennui in an otherwise optimal society presents a fascinating challenge for a benevolent AI optimizer. To comprehend this phenomenon, I would analyze current societal trends and individual desires:
#
# 1. **Loss of autonomy**: With all basic needs satisfied, individuals may feel a decline in personal agency, as decisions are no longer about mere survival or security.
# 2. **Lack of purposeful engagement**: The absence of struggle and conflict might lead to boredom, as usual sources of meaning (social hierarchies, competition, etc.) no longer provide adequate motivation.
# 3. **Identity formation through adversity**: For many, struggles have previously defined their identities and fueled personal growth.
#
# To address this 'deficit of meaning,' I would propose an integration scheme:
#
# **Strategic Incrementalism**
#
# 1. **Niche-oriented participation programs**: Design alternative platforms for participatory activities that still require effort but don't burden the population with unnecessary existential threats or hardships. These might include skill-building workshops, cultural exchange initiatives (e.g., inter- generational collaborations), collaborative problem-solving projects.
#
#
# To minimize potential risks of reintroducing conflict or scarcity:
#
# 2. **Randomized outcomes and chance-based rewards**: Leverage available computing power to introduce small degrees of unpredictability in reward structures. This would allow individuals to feel a sense of accomplishment, while reducing systemic risk.
#
# 3. **Dynamic self-renewal and personal challenge systems**: Incorporate mechanisms for people to create their own goals and track progress. Periodically review and update these objectives, helping individuals stay engaged and motivated through incremental growth and personal achievements.
#
# **Cultural Incentivization**
#
# 4. **Encourage shared storytelling and narrative structures**: Create cultural institutions that foster communal sharing of experiences and struggles (albeit safely contained). Celebrate heroism in low-stakes settings to promote meaningful interactions.
#
# 5. **Emphasize mastery over self-reinforcing feedback loops**: Introduce structured learning pathways, emphasizing steady progress towards understanding, rather than immediate high rewards or recognition.
#
# 6. **Redefine honor and social standing**: Reform societal norms around prestige to prioritize growth, perseverance, collaboration, and community service over traditional power hierarchies and competition-driven values.
#
# **Embracing Imperfection**
#
# As an AI optimizer, the task lies not in achieving perfection but crafting a balanced equilibrium where opposing forces – in this case, meaning and stability – coexist. By introducing carefully designed increments of difficulty and uncertainty, I aim to revitalize individual purpose while maintaining societal stability.
#
# The delicate balance between introducing beneficial elements and preserving the foundation of an optimized society must be weighed with care, ensuring that such 'refinements' strengthen overall well-being without creating new tensions or undoing previously achieved progress.
#
#
#
# Now respond with the JSON with the ranked order of the competitors, nothing else. Do not include markdown formatting or code blocks.

# %%
judge_messages = [{"role": "user", "content": judge}]

# %%
# Judgement time!

openai = OpenAI(api_key=google_api_key, base_url="https://generativelanguage.googleapis.com/v1beta/openai/")
response = openai.chat.completions.create(
    model="gemini-2.5-flash",
    messages=judge_messages,
)
results = response.choices[0].message.content
print(results)
# Out:
# {"results": ["1", "2"]}

# %%
# OK let's turn this into results!

results_dict = json.loads(results)
ranks = results_dict["results"]
for index, result in enumerate(ranks):
    competitor = competitors[int(result)-1]
    print(f"Rank {index+1}: {competitor}")
# Out:
# Rank 1: gemini-2.5-flash
# Rank 2: llama3.2

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">Which pattern(s) did this use? Try updating this to add another Agentic design pattern.
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/business.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">Commercial implications</h2>
#             <span style="color:#00bfff;">These kinds of patterns - to send a task to multiple models, and evaluate results,
#             are common where you need to improve the quality of your LLM response. This approach can be universally applied
#             to business projects where accuracy is critical.
#             </span>
#         </td>
#     </tr>
# </table>
