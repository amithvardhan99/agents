# %% [markdown]
# # Welcome to the start of your adventure in Agentic AI

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Are you ready for action??</h2>
#             <span style="color:#ff7800;">Have you completed all the setup steps in the <a href="../setup/">setup</a> folder?<br/>
#             Have you read the <a href="../README.md">README</a>? Many common questions are answered here!<br/>
#             Have you checked out the guides in the <a href="../guides/01_intro.ipynb">guides</a> folder?<br/>
#             Well in that case, you're ready!!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">This code is a live resource - keep an eye out for my updates</h2>
#             <span style="color:#00bfff;">I push updates regularly. As people ask questions or have problems, I add more examples and improve explanations. As a result, the code below might not be identical to the videos, as I've added more steps and better comments. Consider this like an interactive book that accompanies the lectures.<br/><br/>
#             I try to send emails regularly with important updates related to the course. You can find this in the 'Announcements' section of Udemy in the left sidebar. You can also choose to receive my emails via your Notification Settings in Udemy. I'm respectful of your inbox and always try to add value with my emails!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### And please do remember to contact me if I can help
#
# And I love to connect: https://www.linkedin.com/in/eddonner/
#
#
# ### New to Notebooks like this one? Head over to the guides folder!
#
# Just to check you've already added the Python and Jupyter extensions to Cursor, if not already installed:
# - Open extensions (View >> extensions)
# - Search for python, and when the results show, click on the ms-python one, and Install it if not already installed
# - Search for jupyter, and when the results show, click on the Microsoft one, and Install it if not already installed
# Then View >> Explorer to bring back the File Explorer.
#
# And then:
# 1. Click where it says "Select Kernel" near the top right, and select the option called `.venv (Python 3.12.9)` or similar, which should be the first choice or the most prominent choice. You may need to choose "Python Environments" first.
# 2. Click in each "cell" below, starting with the cell immediately below this text, and press Shift+Enter to run
# 3. Enjoy!
#
# After you click "Select Kernel", if there is no option like `.venv (Python 3.12.9)` then please do the following:
# 1. On Mac: From the Cursor menu, choose Settings >> VS Code Settings (NOTE: be sure to select `VSCode Settings` not `Cursor Settings`);
# On Windows PC: From the File menu, choose Preferences >> VS Code Settings(NOTE: be sure to select `VSCode Settings` not `Cursor Settings`)
# 2. In the Settings search bar, type "venv"
# 3. In the field "Path to folder with a list of Virtual Environments" put the path to the project root, like C:\Users\username\projects\agents (on a Windows PC) or /Users/username/projects/agents (on Mac or Linux).
# And then try again.
#
# Having problems with missing Python versions in that list? Have you ever used Anaconda before? It might be interferring. Quit Cursor, bring up a new command line, and make sure that your Anaconda environment is deactivated:
# `conda deactivate`
# And if you still have any problems with conda and python versions, it's possible that you will need to run this too:
# `conda config --set auto_activate_base false`
# and then from within the Agents directory, you should be able to run `uv python list` and see the Python 3.12 version.

# %%
# First let's do an import. If you get an Import Error, double check that your Kernel is correct..

from dotenv import load_dotenv

# %%
# Next it's time to load the API keys into environment variables
# If this returns false, see the next cell!

load_dotenv(override=True)
# Out:
# False

# %% [markdown]
# ### Wait, did that just output `False`??
#
# If so, the most common reason is that you didn't save your `.env` file after adding the key! Be sure to have saved.
#
# Also, make sure the `.env` file is named precisely `.env` and is in the project root directory (`agents`)
#
# By the way, your `.env` file should have a stop symbol next to it in Cursor on the left, and that's actually a good thing: that's Cursor saying to you, "hey, I realize this is a file filled with secret information, and I'm not going to send it to an external AI to suggest changes, because your keys should not be shown to anyone else."

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Final reminders</h2>
#             <span style="color:#ff7800;">1. If you're not confident about Environment Variables or Web Endpoints / APIs, please read Topics 3 and 5 in this <a href="../guides/04_technical_foundations.ipynb">technical foundations guide</a>.<br/>
#             2. If you want to use AIs other than OpenAI, like Gemini, DeepSeek or Ollama (free), please see the first section in this <a href="../guides/09_ai_apis_and_ollama.ipynb">AI APIs guide</a>.<br/>
#             3. If you ever get a Name Error in Python, you can always fix it immediately; see the last section of this <a href="../guides/06_python_foundations.ipynb">Python Foundations guide</a> and follow both tutorials and exercises.<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# Check the key - if you're not using OpenAI, check whichever key you're using! Ollama doesn't need a key.

import os
openai_api_key = os.getenv('OPENAI_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set - please head to the troubleshooting guide in the setup folder")
# Out:
# OpenAI API Key not set - please head to the troubleshooting guide in the setup folder

# %%
# And now - the all important import statement
# If you get an import error - head over to troubleshooting in the Setup folder
# Even for other LLM providers like Gemini, you still use this OpenAI import - see Guide 9 for why

from openai import OpenAI

# %%
# And now we'll create an instance of the OpenAI class
# If you're not sure what it means to create an instance of a class - head over to the guides folder (guide 6)!
# If you get a NameError - head over to the guides folder (guide 6)to learn about NameErrors - always instantly fixable
# If you're not using OpenAI, you just need to slightly modify this - precise instructions are in the AI APIs guide (guide 9)

openai = OpenAI()
# Out:
# ---------------------------------------------------------------------------
# OpenAIError                               Traceback (most recent call last)
# Cell In[5], line 6
#       1 # And now we'll create an instance of the OpenAI class
#       2 # If you're not sure what it means to create an instance of a class - head over to the guides folder (guide 6)!
#       3 # If you get a NameError - head over to the guides folder (guide 6)to learn about NameErrors - always instantly fixable
#       4 # If you're not using OpenAI, you just need to slightly modify this - precise instructions are in the AI APIs guide (guide 9)
# ----> 6 openai = OpenAI()
#
# File c:\Users\amith\Documents\GitHub\agents\.venv\Lib\site-packages\openai\_client.py:135, in OpenAI.__init__(self, api_key, organization, project, webhook_secret, base_url, websocket_base_url, timeout, max_retries, default_headers, default_query, http_client, _strict_response_validation)
#     133     api_key = os.environ.get("OPENAI_API_KEY")
#     134 if api_key is None:
# --> 135     raise OpenAIError(
#     136         "The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable"
#     137     )
#     138 if callable(api_key):
#     139     self.api_key = ""
#
# OpenAIError: The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable

# %%
# Create a list of messages in the familiar OpenAI format

messages = [{"role": "user", "content": "What is 2+2?"}]

# %%
# And now call it! Any problems, head to the troubleshooting guide
# This uses GPT 4.1 nano, the incredibly cheap model
# The APIs guide (guide 9) has exact instructions for using even cheaper or free alternatives to OpenAI
# If you get a NameError, head to the guides folder (guide 6) to learn about NameErrors - always instantly fixable

response = openai.chat.completions.create(
    model="gpt-4.1-nano",
    messages=messages
)

print(response.choices[0].message.content)

# %%
# And now - let's ask for a question:

question = "Please propose a hard, challenging question to assess someone's IQ. Respond only with the question."
messages = [{"role": "user", "content": question}]

# %%
# ask it - this uses GPT 4.1 mini, still cheap but more powerful than nano

response = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)

question = response.choices[0].message.content

print(question)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 3
#       1 # ask it - this uses GPT 4.1 mini, still cheap but more powerful than nano
# ----> 3 response = openai.chat.completions.create(
#       4     model="gpt-4.1-mini",
#       5     messages=messages
#       6 )
#       8 question = response.choices[0].message.content
#      10 print(question)
#
# NameError: name 'openai' is not defined

# %%
# form a new messages list
messages = [{"role": "user", "content": question}]

# %%
# Ask it again

response = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)

answer = response.choices[0].message.content
print(answer)

# %%
from IPython.display import Markdown, display

display(Markdown(answer))

# %% [markdown]
# # Congratulations!
#
# That was a small, simple step in the direction of Agentic AI, with your new environment!
#
# Next time things get more interesting...

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">Now try this commercial application:<br/>
#             First ask the LLM to pick a business area that might be worth exploring for an Agentic AI opportunity.<br/>
#             Then ask the LLM to present a pain-point in that industry - something challenging that might be ripe for an Agentic solution.<br/>
#             Finally have 3 third LLM call propose the Agentic AI solution. <br/>
#             We will cover this at up-coming labs, so don't worry if you're unsure.. just give it a try!
#             </span>
#         </td>
#     </tr>
# </table>

# %%
from ollama import Client,chat

# %%
# First create the messages:

messages = [{"role": "user", "content": "Can you provide me a great idea for setting up a business? Please research the internet and provide me the most creative and innovative one. Retrieve like 10 ideas and finalise on the best one."}]

# Then make the first call:

#client = Client()
response = chat(
    model = "llama3.2:3b",
    messages = messages
)

# Then read the business idea:

business_idea = response.message.content
print(business_idea)

# And repeat! In the next message, include the business idea within the message
# Out:
# ---------------------------------------------------------------------------
# ConnectionError                           Traceback (most recent call last)
# Cell In[9], line 8
#       3 messages = [{"role": "user", "content": "Can you provide me a great idea for setting up a business? Please research the internet and provide me the most creative and innovative one. Retrieve like 10 ideas and finalise on the best one."}]
#       5 # Then make the first call:
#       6
#       7 #client = Client()
# ----> 8 response = chat(
#       9     model = "llama3.2:3b",
#      10     messages = messages
#      11 )
#      13 # Then read the business idea:
#      15 business_idea = response.message.content
#
# File c:\Users\amith\Documents\GitHub\agents\.venv\Lib\site-packages\ollama\_client.py:351, in Client.chat(self, model, messages, tools, stream, think, format, options, keep_alive)
#     306 def chat(
#     307   self,
#     308   model: str = '',
#    (...)    316   keep_alive: Optional[Union[float, str]] = None,
#     317 ) -> Union[ChatResponse, Iterator[ChatResponse]]:
#     318   """
#     319   Create a chat response using the requested model.
#     320
#    (...)    349   Returns `ChatResponse` if `stream` is `False`, otherwise returns a `ChatResponse` generator.
#     350   """
# --> 351   return self._request(
#     352     ChatResponse,
#     353     'POST',
#     354     '/api/chat',
#     355     json=ChatRequest(
#     356       model=model,
#     357       messages=list(_copy_messages(messages)),
#     358       tools=list(_copy_tools(tools)),
#     359       stream=stream,
#     360       think=think,
#     361       format=format,
#     362       options=options,
#     363       keep_alive=keep_alive,
#     364     ).model_dump(exclude_none=True),
#     365     stream=stream,
#     366   )
#
# File c:\Users\amith\Documents\GitHub\agents\.venv\Lib\site-packages\ollama\_client.py:189, in Client._request(self, cls, stream, *args, **kwargs)
#     185         yield cls(**part)
#     187   return inner()
# --> 189 return cls(**self._request_raw(*args, **kwargs).json())
#
# File c:\Users\amith\Documents\GitHub\agents\.venv\Lib\site-packages\ollama\_client.py:135, in Client._request_raw(self, *args, **kwargs)
#     133   raise ResponseError(e.response.text, e.response.status_code) from None
#     134 except httpx.ConnectError:
# --> 135   raise ConnectionError(CONNECTION_ERROR_MESSAGE) from None
#
# ConnectionError: Failed to connect to Ollama. Please check that Ollama is downloaded, running and accessible. https://ollama.com/download

# %%
# First create the messages:

messages = [{"role": "user", "content": f"{business_idea}\n\nThe above are the business ideas. Pick the best business idea, and provide me the most difficult part of it to implement in the real world. "}]

# Then make the first call:

#client = Client()
response = chat(
    model = "llama3.2:3b",
    messages = messages
)

# Then read the business idea:

difficult_part = response.message.content
print(difficult_part)

# And repeat! In the next message, include the business idea within the message
# Out:
# After reviewing the top 3 business ideas you selected, I think the most challenging part to implement in the real world is for **Eco-Friendly Plant-Based Food Subscription Service - "GreenBloom"**.
#
# Here's why:
#
# 1. **Supply Chain Management**: Sourcing high-quality, sustainable ingredients from local farmers and suppliers requires a reliable supply chain management system. This involves building relationships with farmers, managing inventory, and ensuring that products are delivered on time and in good condition.
# 2. **Food Safety and Handling**: Ensuring the safety and handling of perishable food products is a critical concern for any food subscription service. GreenBloom will need to implement strict quality control measures to prevent contamination, spoilage, and foodborne illnesses.
# 3. **Seasonal and Regional Produce**: To offer diverse and seasonal produce options, GreenBloom will need to navigate the complexities of regional produce availability, storage, and transportation. This may require partnerships with local farmers' cooperatives, wholesalers, or distributors.
# 4. **Food Waste Reduction**: Reducing food waste is a significant challenge for any food subscription service. GreenBloom will need to implement strategies such as meal planning, portion control, and packaging optimization to minimize waste and ensure that customers receive only the freshest produce.
#
# Implementing these aspects of GreenBloom's business model will require careful planning, collaboration with stakeholders, and investment in technology and infrastructure to ensure the service is delivered efficiently and sustainably.
#
# The most difficult part to implement in the real world for **Eco-Friendly Plant-Based Food Subscription Service - "GreenBloom"** includes:
#
# * Establishing a reliable supply chain management system
# * Implementing strict food safety and handling protocols
# * Managing seasonal and regional produce availability
# * Reducing food waste through efficient meal planning, portion control, and packaging optimization
#
# These challenges will require careful consideration of logistics, operations, and customer service to ensure the success of GreenBloom.

# %%
# First create the messages:

messages = [{"role": "user", "content": f"{difficult_part}\n\nThe above is the most difficult part of the business idea. Provide me a detailed business plan to overcome this difficulty. "}]

# Then make the first call:

#client = Client()
response = chat(
    model = "llama3.2:3b",
    messages = messages
)

# Then read the business idea:

final_plan = response.message.content
print(final_plan)

# And repeat! In the next message, include the business idea within the message
# Out:
# Business Plan: Overcoming Challenges in Establishing "GreenBloom"
#
# **Executive Summary**
#
# GreenBloom aims to provide a sustainable and convenient way for individuals to adopt an eco-friendly plant-based lifestyle by offering a monthly subscription service that delivers fresh, seasonal produce to customers' doors. To overcome the challenges associated with establishing this business, we have developed a comprehensive plan to ensure successful implementation.
#
# **I. Supply Chain Management**
#
# 1. **Establish Partnerships**: Collaborate with local farmers, suppliers, and distributors to establish a reliable network for sourcing high-quality produce.
# 2. **Implement Technology**: Utilize a cloud-based inventory management system (e.g., TradeGecko) to track inventory levels, monitor shipments, and optimize logistics.
# 3. **Develop Relationships**: Build strong relationships with farmers and suppliers through regular communication, quality control checks, and fair pricing.
# 4. **Invest in Warehousing**: Rent or lease a suitable warehouse space for storage, processing, and packaging of produce.
#
# **Initial Investment:** $100,000 (warehousing rental, inventory management software, and initial marketing expenses)
#
# **Monthly Expenses:**
#
# * Warehouse rental: $5,000
# * Inventory management software: $500
# * Marketing expenses: $2,000
#
# Total monthly expenses: $7,500
#
# **II. Food Safety and Handling**
#
# 1. **Implement Quality Control Measures**: Establish a quality control team to conduct regular inspections of produce, packaging, and storage facilities.
# 2. **Train Staff**: Provide ongoing training for staff on food safety protocols, handling procedures, and sanitation practices.
# 3. **Invest in Sanitation Equipment**: Install sanitation equipment (e.g., refrigerators, freezers) to maintain proper temperatures and cleanliness standards.
# 4. **Comply with Regulations**: Ensure compliance with all relevant regulations and guidelines, such as USDA and FDA standards.
#
# **Initial Investment:** $50,000 (quality control team training, sanitation equipment, and regulatory compliance expenses)
#
# **Monthly Expenses:**
#
# * Quality control team salaries: $2,500
# * Sanitation equipment maintenance: $1,000
# * Regulatory compliance fees: $500
#
# Total monthly expenses: $4,000
#
# **III. Seasonal and Regional Produce Availability**
#
# 1. **Develop Strategic Partnerships**: Collaborate with local farmers' cooperatives, wholesalers, or distributors to source seasonal produce.
# 2. **Implement Transportation Network**: Establish relationships with transportation companies to ensure timely delivery of produce.
# 3. **Invest in Market Research**: Conduct regular market research to identify trends and demand for specific produce items.
#
# **Initial Investment:** $30,000 (market research expenses, partnerships development)
#
# **Monthly Expenses:**
#
# * Market research expenses: $1,500
# * Transportation costs: $2,000
#
# Total monthly expenses: $3,500
#
# **IV. Food Waste Reduction**
#
# 1. **Meal Planning and Portion Control**: Implement meal planning tools to minimize food waste and optimize produce usage.
# 2. **Packaging Optimization**: Invest in packaging solutions that reduce food waste and minimize environmental impact.
# 3. **Customer Education**: Educate customers on the importance of reducing food waste and provide tips for minimizing waste at home.
#
# **Initial Investment:** $20,000 (meal planning software, packaging optimization expenses)
#
# **Monthly Expenses:**
#
# * Meal planning software subscription: $500
# * Packaging optimization costs: $1,000
#
# Total monthly expenses: $1,500
#
# **Conclusion**
#
# Establishing GreenBloom requires careful planning, collaboration with stakeholders, and investment in technology and infrastructure. By implementing these strategies, we can overcome the challenges associated with our business model and ensure successful implementation.
#
# **Key Performance Indicators (KPIs)**
#
# * Supply chain management efficiency
# * Food safety ratings
# * Customer satisfaction (measured through surveys and reviews)
# * Inventory levels and storage capacity utilization
# * Food waste reduction rates
# * Revenue growth and customer acquisition rates
#
# By monitoring these KPIs, we can make data-driven decisions to optimize our operations, improve customer satisfaction, and increase revenue.
