# %% [markdown]
# # Welcome to the start of your adventure in Agentic AI

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Are you ready for action??</h2>
#             <span style="color:#ff7800;">Have you completed all the setup steps in the <a href="../setup/">setup</a> folder?<br/>
#             Have you read the <a href="../README.md">README</a>? Many common questions are answered here!<br/>
#             Have you checked out the guides in the <a href="../guides/01_intro.ipynb">guides</a> folder?<br/>
#             Well in that case, you're ready!!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">This code is a live resource - keep an eye out for my updates</h2>
#             <span style="color:#00bfff;">I push updates regularly. As people ask questions or have problems, I add more examples and improve explanations. As a result, the code below might not be identical to the videos, as I've added more steps and better comments. Consider this like an interactive book that accompanies the lectures.<br/><br/>
#             I try to send emails regularly with important updates related to the course. You can find this in the 'Announcements' section of Udemy in the left sidebar. You can also choose to receive my emails via your Notification Settings in Udemy. I'm respectful of your inbox and always try to add value with my emails!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### And please do remember to contact me if I can help
#
# And I love to connect: https://www.linkedin.com/in/eddonner/
#
#
# ### New to Notebooks like this one? Head over to the guides folder!
#
# Just to check you've already added the Python and Jupyter extensions to Cursor, if not already installed:
# - Open extensions (View >> extensions)
# - Search for python, and when the results show, click on the ms-python one, and Install it if not already installed
# - Search for jupyter, and when the results show, click on the Microsoft one, and Install it if not already installed
# Then View >> Explorer to bring back the File Explorer.
#
# And then:
# 1. Click where it says "Select Kernel" near the top right, and select the option called `.venv (Python 3.12.9)` or similar, which should be the first choice or the most prominent choice. You may need to choose "Python Environments" first.
# 2. Click in each "cell" below, starting with the cell immediately below this text, and press Shift+Enter to run
# 3. Enjoy!
#
# After you click "Select Kernel", if there is no option like `.venv (Python 3.12.9)` then please do the following:
# 1. On Mac: From the Cursor menu, choose Settings >> VS Code Settings (NOTE: be sure to select `VSCode Settings` not `Cursor Settings`);
# On Windows PC: From the File menu, choose Preferences >> VS Code Settings(NOTE: be sure to select `VSCode Settings` not `Cursor Settings`)
# 2. In the Settings search bar, type "venv"
# 3. In the field "Path to folder with a list of Virtual Environments" put the path to the project root, like C:\Users\username\projects\agents (on a Windows PC) or /Users/username/projects/agents (on Mac or Linux).
# And then try again.
#
# Having problems with missing Python versions in that list? Have you ever used Anaconda before? It might be interferring. Quit Cursor, bring up a new command line, and make sure that your Anaconda environment is deactivated:
# `conda deactivate`
# And if you still have any problems with conda and python versions, it's possible that you will need to run this too:
# `conda config --set auto_activate_base false`
# and then from within the Agents directory, you should be able to run `uv python list` and see the Python 3.12 version.

# %%
# First let's do an import. If you get an Import Error, double check that your Kernel is correct..

from dotenv import load_dotenv

# %%
# Next it's time to load the API keys into environment variables
# If this returns false, see the next cell!

load_dotenv(override=True)
# Out:
# False

# %% [markdown]
# ### Wait, did that just output `False`??
#
# If so, the most common reason is that you didn't save your `.env` file after adding the key! Be sure to have saved.
#
# Also, make sure the `.env` file is named precisely `.env` and is in the project root directory (`agents`)
#
# By the way, your `.env` file should have a stop symbol next to it in Cursor on the left, and that's actually a good thing: that's Cursor saying to you, "hey, I realize this is a file filled with secret information, and I'm not going to send it to an external AI to suggest changes, because your keys should not be shown to anyone else."

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Final reminders</h2>
#             <span style="color:#ff7800;">1. If you're not confident about Environment Variables or Web Endpoints / APIs, please read Topics 3 and 5 in this <a href="../guides/04_technical_foundations.ipynb">technical foundations guide</a>.<br/>
#             2. If you want to use AIs other than OpenAI, like Gemini, DeepSeek or Ollama (free), please see the first section in this <a href="../guides/09_ai_apis_and_ollama.ipynb">AI APIs guide</a>.<br/>
#             3. If you ever get a Name Error in Python, you can always fix it immediately; see the last section of this <a href="../guides/06_python_foundations.ipynb">Python Foundations guide</a> and follow both tutorials and exercises.<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# Check the key - if you're not using OpenAI, check whichever key you're using! Ollama doesn't need a key.

import os
openai_api_key = os.getenv('OPENAI_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set - please head to the troubleshooting guide in the setup folder")

# %%
# And now - the all important import statement
# If you get an import error - head over to troubleshooting in the Setup folder
# Even for other LLM providers like Gemini, you still use this OpenAI import - see Guide 9 for why

from openai import OpenAI

# %%
# And now we'll create an instance of the OpenAI class
# If you're not sure what it means to create an instance of a class - head over to the guides folder (guide 6)!
# If you get a NameError - head over to the guides folder (guide 6)to learn about NameErrors - always instantly fixable
# If you're not using OpenAI, you just need to slightly modify this - precise instructions are in the AI APIs guide (guide 9)

openai = OpenAI()

# %%
# Create a list of messages in the familiar OpenAI format

messages = [{"role": "user", "content": "What is 2+2?"}]

# %%
# And now call it! Any problems, head to the troubleshooting guide
# This uses GPT 4.1 nano, the incredibly cheap model
# The APIs guide (guide 9) has exact instructions for using even cheaper or free alternatives to OpenAI
# If you get a NameError, head to the guides folder (guide 6) to learn about NameErrors - always instantly fixable

response = openai.chat.completions.create(
    model="gpt-4.1-nano",
    messages=messages
)

print(response.choices[0].message.content)

# %%
# And now - let's ask for a question:

question = "Please propose a hard, challenging question to assess someone's IQ. Respond only with the question."
messages = [{"role": "user", "content": question}]

# %%
# ask it - this uses GPT 4.1 mini, still cheap but more powerful than nano

response = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)

question = response.choices[0].message.content

print(question)

# %%
# form a new messages list
messages = [{"role": "user", "content": question}]

# %%
# Ask it again

response = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)

answer = response.choices[0].message.content
print(answer)

# %%
from IPython.display import Markdown, display

display(Markdown(answer))

# %% [markdown]
# # Congratulations!
#
# That was a small, simple step in the direction of Agentic AI, with your new environment!
#
# Next time things get more interesting...

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">Now try this commercial application:<br/>
#             First ask the LLM to pick a business area that might be worth exploring for an Agentic AI opportunity.<br/>
#             Then ask the LLM to present a pain-point in that industry - something challenging that might be ripe for an Agentic solution.<br/>
#             Finally have 3 third LLM call propose the Agentic AI solution. <br/>
#             We will cover this at up-coming labs, so don't worry if you're unsure.. just give it a try!
#             </span>
#         </td>
#     </tr>
# </table>

# %%
from ollama import Client,chat

# %%
# First create the messages:

messages = [{"role": "user", "content": "Can you provide me a great idea for setting up a business? Please research the internet and provide me the most creative and innovative one. Retrieve like 10 ideas and finalise on the best one."}]

# Then make the first call:

#client = Client()
response = chat(
    model = "llama3.2:3b",
    messages = messages
)

# Then read the business idea:

business_idea = response.message.content
print(business_idea)

# And repeat! In the next message, include the business idea within the message
# Out:
# After researching the internet, I've come up with 10 innovative business ideas that are creative, unique, and have potential for growth. After reviewing them, I've selected the top 3 ideas that I think have the most potential:
#
# **Idea 1: Eco-Friendly Plant-Based Food Subscription Service - "GreenBloom"**
#
# Concept: GreenBloom is a subscription-based service that delivers fresh, organic plant-based produce to customers' doors on a monthly basis. Partner with local farmers and suppliers to source high-quality, sustainable ingredients.
#
# Revenue Streams:
#
# * Monthly subscription fees
# * Sales of packaged produce products (e.g., frozen meals, soups)
# * Partnerships with health food stores and wellness centers
#
# Marketing Strategy: Utilize social media platforms (Instagram, Facebook, Pinterest) to showcase the brand's commitment to sustainability and healthy eating. Collaborate with influencers, bloggers, and local chefs to promote the service.
#
# **Idea 2: AI-Powered Mental Wellness App - "MindScape"**
#
# Concept: MindScape is an AI-driven mental wellness app that provides personalized meditation sessions, mood tracking, and stress management tools. Partner with licensed therapists and mental health professionals to develop a robust platform.
#
# Revenue Streams:
#
# * Subscription fees for access to premium content
# * Advertising (e.g., sponsored meditation sessions)
# * Partnerships with insurance companies and employers to offer discounted plans
#
# Marketing Strategy: Utilize the latest AI technologies to create an immersive user experience. Leverage social media platforms, online advertising, and targeted promotions to reach a wide audience.
#
# **Idea 3: Customizable, 3D-Printed Furniture Assembly Service - "Furnishify"**
#
# Concept: Furnishify is a custom furniture assembly service that leverages cutting-edge 3D printing technology. Partner with skilled craftsmen to design and produce bespoke furniture pieces.
#
# Revenue Streams:
#
# * Hourly assembly fees
# * Sales of assembled furniture products (e.g., coffee tables, beds)
# * Partnerships with interior designers and architects to offer customized services
#
# Marketing Strategy: Utilize social media platforms (Instagram, Facebook) to showcase the unique 3D printing capabilities. Partner with influencers, bloggers, and online magazines to promote the service.
#
# **Idea 4: Autonomous, Electric Bike Delivery Service - "BikeGo"**
#
# Concept: BikeGo is an autonomous electric bike delivery service that connects customers with local bike shops and repair services. Utilize AI-powered navigation systems and mapping technology to optimize routes.
#
# Revenue Streams:
#
# * Monthly subscription fees for access to designated bike lanes
# * Sales of assembled bicycles and accessories (e.g., helmets, locks)
# * Partnerships with bike manufacturers and suppliers
#
# Marketing Strategy: Utilize social media platforms (Instagram, Facebook) to showcase the unique delivery service. Partner with influencers, bloggers, and online publications to promote the service.
#
# **Idea 5: Virtual Reality Training Platform for Workplace Wellness - "WellVista"**
#
# Concept: WellVista is a virtual reality training platform that offers immersive workplace wellness experiences. Partner with employers to offer customized VR programs for employees' physical and mental well-being.
#
# Revenue Streams:
#
# * Subscription fees for access to premium content
# * Advertising (e.g., sponsored VR sessions)
# * Partnerships with health insurance companies and HR departments
#
# Marketing Strategy: Utilize the latest VR technologies to create engaging user experiences. Partner with employers, industry associations, and healthcare professionals to promote the service.
#
# **Idea 6: On-Demand, Sustainable Supply Chain Management - "EcoCycle"**
#
# Concept: EcoCycle is an on-demand supply chain management platform that connects companies with local suppliers and manufacturers for sustainable products. Utilize data analytics and machine learning algorithms to optimize logistics and reduce carbon emissions.
#
# Revenue Streams:
#
# * Subscription fees for access to premium inventory management tools
# * Sales of assembled products (e.g., eco-friendly cleaning supplies)
# * Partnerships with governments and regulatory bodies to promote sustainability initiatives
#
# Marketing Strategy: Utilize social media platforms (Twitter, LinkedIn) to showcase the platform's commitment to sustainability. Partner with influencers, bloggers, and industry associations to promote the service.
#
# **Idea 7: Personalized, AI-Driven Home Appliance Repair Service - "ApplianceAid"**
#
# Concept: ApplianceAid is an AI-driven home appliance repair service that provides personalized recommendations for fixing common issues. Partner with skilled technicians and manufacturers to offer customized support.
#
# Revenue Streams:
#
# * Hourly repair fees
# * Sales of assembled appliances (e.g., kitchen gadgets)
# * Partnerships with appliance manufacturers
#
# Marketing Strategy: Utilize social media platforms (Instagram, Facebook) to showcase the unique service offerings. Partner with influencers, bloggers, and online publications to promote the service.
#
# **Idea 8: Online Community Platform for Mental Health Support - "MentalConnect"**
#
# Concept: MentalConnect is an online community platform that connects people struggling with mental health issues with trained therapists and support groups. Utilize AI-powered chatbots to facilitate communication.
#
# Revenue Streams:
#
# * Subscription fees for access to premium content
# * Advertising (e.g., sponsored therapy sessions)
# * Partnerships with insurance companies and employers
#
# Marketing Strategy: Utilize social media platforms (Facebook, Instagram) to showcase the platform's commitment to mental health support. Partner with influencers, bloggers, and industry associations to promote the service.
#
# **Idea 9: AI-Powered Personalized Nutrition Planning Service - "NutriGarden"**
#
# Concept: NutriGarden is an AI-driven personalized nutrition planning service that provides tailored meal plans based on users' dietary needs and preferences. Utilize machine learning algorithms to optimize nutrient intake.
#
# Revenue Streams:
#
# * Subscription fees for access to premium content
# * Sales of assembled meals (e.g., grocery kits)
# * Partnerships with health food stores and wellness centers
#
# Marketing Strategy: Utilize social media platforms (Instagram, Facebook) to showcase the unique service offerings. Partner with influencers, bloggers, and online publications to promote the service.
#
# **Idea 10: Digital Platform for Sustainable Fashion - "SustainableStyle"**
#
# Concept: SustainableStyle is a digital platform that connects consumers with sustainable fashion brands, suppliers, and designers. Utilize data analytics and social media marketing to promote eco-friendly fashion options.
#
# Revenue Streams:
#
# * Subscription fees for access to premium content
# * Advertising (e.g., sponsored fashion articles)
# * Sales of assembled clothing products (e.g., second-hand stores)
#
# Marketing Strategy: Utilize social media platforms (Instagram, Facebook) to showcase the platform's commitment to sustainability. Partner with influencers, bloggers, and industry associations to promote the service.
#
# After reviewing these 10 innovative business ideas, I've selected the top 3 as the most creative and promising:
#
# 1. **Eco-Friendly Plant-Based Food Subscription Service - "GreenBloom"**
# 2. **AI-Powered Mental Wellness App - "MindScape"**
# 3. **Customizable, 3D-Printed Furniture Assembly Service - "Furnishify"**
#
# These ideas have the potential to disrupt traditional industries and create new markets for sustainable products and services. By leveraging cutting-edge technologies, innovative marketing strategies, and customer-centric approaches, these businesses can differentiate themselves and achieve significant growth and success.

# %%
# First create the messages:

messages = [{"role": "user", "content": f"{business_idea}\n\nThe above are the business ideas. Pick the best business idea, and provide me the most difficult part of it to implement in the real world. "}]

# Then make the first call:

#client = Client()
response = chat(
    model = "llama3.2:3b",
    messages = messages
)

# Then read the business idea:

difficult_part = response.message.content
print(difficult_part)

# And repeat! In the next message, include the business idea within the message
# Out:
# After reviewing the top 3 business ideas you selected, I think the most challenging part to implement in the real world is for **Eco-Friendly Plant-Based Food Subscription Service - "GreenBloom"**.
#
# Here's why:
#
# 1. **Supply Chain Management**: Sourcing high-quality, sustainable ingredients from local farmers and suppliers requires a reliable supply chain management system. This involves building relationships with farmers, managing inventory, and ensuring that products are delivered on time and in good condition.
# 2. **Food Safety and Handling**: Ensuring the safety and handling of perishable food products is a critical concern for any food subscription service. GreenBloom will need to implement strict quality control measures to prevent contamination, spoilage, and foodborne illnesses.
# 3. **Seasonal and Regional Produce**: To offer diverse and seasonal produce options, GreenBloom will need to navigate the complexities of regional produce availability, storage, and transportation. This may require partnerships with local farmers' cooperatives, wholesalers, or distributors.
# 4. **Food Waste Reduction**: Reducing food waste is a significant challenge for any food subscription service. GreenBloom will need to implement strategies such as meal planning, portion control, and packaging optimization to minimize waste and ensure that customers receive only the freshest produce.
#
# Implementing these aspects of GreenBloom's business model will require careful planning, collaboration with stakeholders, and investment in technology and infrastructure to ensure the service is delivered efficiently and sustainably.
#
# The most difficult part to implement in the real world for **Eco-Friendly Plant-Based Food Subscription Service - "GreenBloom"** includes:
#
# * Establishing a reliable supply chain management system
# * Implementing strict food safety and handling protocols
# * Managing seasonal and regional produce availability
# * Reducing food waste through efficient meal planning, portion control, and packaging optimization
#
# These challenges will require careful consideration of logistics, operations, and customer service to ensure the success of GreenBloom.

# %%
# First create the messages:

messages = [{"role": "user", "content": f"{difficult_part}\n\nThe above is the most difficult part of the business idea. Provide me a detailed business plan to overcome this difficulty. "}]

# Then make the first call:

#client = Client()
response = chat(
    model = "llama3.2:3b",
    messages = messages
)

# Then read the business idea:

final_plan = response.message.content
print(final_plan)

# And repeat! In the next message, include the business idea within the message
